# %% [markdown]
# ### Settings

# %%
# Change when commiting to prevent leaks
path_root = ""

# %% [markdown]
# ### Imports

# %%
import plotly.express as px
import plotly.graph_objects as go
import xarray as xr

from visualization_scripts.visualization_script_spatial import plot_salinity, plot_temperature, plot_volume

# %% [markdown]
# ## Plot the volume

# %%
plot_volume(path_root)
# Out:
#         <iframe
#             width="100%"
#             height="468"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## Plot the temperature

# %%
plot_temperature(path_root)

# %% [markdown]
# ## Plot the salinity

# %%
plot_salinity(path_root)
